# %% [markdown]
# <a href="https://colab.research.google.com/github/hafizihsani/data-science-2026/blob/main/Pertemuan1_Muhamad_Hafiz_ihsani_250401020155.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pertemuan 1 — Pengenalan Data Science
# Nama : Muhammad Hafiz Ihsani
#
# NIM : 250401020155
#
# Mata Kuliah: Data Science — S1 PJJ Informatika
#
# Kelas: IF401

# %% [markdown]
# SEL 1: Output sederhana

# %%
print("Hello Dunia ini Adalah data Science")
# Out:
# Hello Dunia ini Adalah data Science

# %% [markdown]
# SEL 2: Variabel & tipe data

# %%
nama = "Muhammad Hafiz Ihsani" # String
angkatan = 2026 # Integer
ipk = 3.58 # Float
aktif = True # Boolean
print(f"Nama : {nama}")
print(f"Angkatan: {angkatan}")
print(f"IPK : {ipk}")
print(f"Aktif : {aktif}")
# Out:
# Nama : Muhammad Hafiz Ihsani
# Angkatan: 2026
# IPK : 3.58
# Aktif : True

# %% [markdown]
# Sel 3 : List & Pengulangan

# %%
tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]
print("\nTools Data Science yang akan kita pelajari:")
for i in tools:
    print(i)
# Out:
# Tools Data Science yang akan kita pelajari:
# Python
# Google Colab
# Jupyter Notebook
# GitHub

# %% [markdown]
# SEL 4: Fungsi sederhana

# %%
def perkenalan(nama, prodi, angkatan):
    """Fungsi untuk menampilkan perkenalan mahasiswa."""
    return f"Hai! Perkenalkan nama saya {nama} dari {prodi}, angkatan {angkatan}."

perkenalan("Hafiz Ihsani", "PJJ Informatika", 2026)
# Out:
# 'Hai! Perkenalkan nama saya Hafiz Ihsani dari PJJ Informatika, angkatan 2026.'

# %% [markdown]
# **Kesimpulan Akhir**
#
# Pembelajaran ini berfokus pada pengenalan dasar-dasar pemrograman Python yang penting sebagai fondasi awal dalam Data Science. Berikut adalah poin-poin utama yang dipelajari:
#
# **Pengenalan Output: **Mempelajari cara menampilkan teks sederhana ke layar menggunakan fungsi print().
#
# **Variabel dan Tipe Data:** Memahami cara menyimpan data dengan berbagai tipe data seperti String (teks), Integer (angka bulat), Float (angka desimal), dan Boolean (logika benar/salah), serta teknik menampilkan data tersebut menggunakan f-string.
#
# **List dan Pengulangan:** Mempelajari struktur data List untuk menyimpan sekumpulan item dan penggunaan perulangan for untuk memproses atau menampilkan setiap elemen di dalam list tersebut secara efisien.
#
# **Fungsi Sederhana:** Memahami konsep modularitas kode dengan membuat fungsi sendiri menggunakan kata kunci def, lengkap dengan parameter input untuk membuat kode yang dapat digunakan kembali (reusable).
